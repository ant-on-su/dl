# %% [markdown]
# # Tuning Neural Networks

# %%
import os
import shutil

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# import sys
# sys.path.insert(0, '../')

# %matplotlib inline
plt.rcParams["figure.figsize"] = 15, 6

# %%
# load data
from sklearn.datasets import load_wine
X, y = load_wine(return_X_y=True)
df = pd.DataFrame(X, y).reset_index().rename(columns={'index': 'label'})
df = df.assign(label = np.where(df['label'] > 1, 1, 0))
df['label'].value_counts()
# Out:
# 0    130
# 1     48
# Name: label, dtype: int64

# %%
# create categorical
df[1] = pd.qcut(df[1], q=3, labels=["a", "b", "c"], duplicates="drop")

# %%
# set X, y
X = df.iloc[:, 1:].values
y = df.iloc[:, 0].values

# %%
# preprocess
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# encoding feature 1
labelencoder = LabelEncoder()
X[:, 2] = labelencoder.fit_transform(X[:, 2])
X.shape
# Out:
# (178, 13)

# %%
# creating dummies for feature 1
from sklearn.compose import ColumnTransformer

# The arg ([1]) is the list of columns we want to transform in this step
# replacing feature with three categories with two dummy variables
ct = ColumnTransformer([("onehot", OneHotEncoder(drop='first'),[1])], remainder="passthrough")
X = ct.fit_transform(X)
X.shape  # check to see we have one more column
# Out:
# (178, 14)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 100)

# %%
# feature Scaling
# we need to make sure that no information from the test set leaks into the train set

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test) # note here how the scaler is fit only on the train set

# %% [markdown]
# ---
# ## Building a simple Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

# %%
def make_model(model_name):
    
    model = Sequential(name=model_name)
    # starting point number of layers: 2 hidden
    # starting point number of nodes: rule of thumb = average of input and output nodes
    model.add(layers.Dense(name="FullyConnected_1", units=6, activation="relu", input_dim=14))
    model.add(layers.Dense(name="FullyConnected_2", units=6, activation="relu"))
    model.add(layers.Dense(name="FullyConnected_OutputLayer", units=1, activation="sigmoid"))
    
    return model

model = make_model("SimpleModel")
model.summary()
# Out:
# Model: "SimpleModel"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  FullyConnected_1 (Dense)    (None, 6)                 90
#
#  FullyConnected_2 (Dense)    (None, 6)                 42
#
#  FullyConnected_OutputLayer   (None, 1)                7
#  (Dense)
#
# =================================================================
# Total params: 139
# Trainable params: 139
# Non-trainable params: 0
# _________________________________________________________________

# %%
# trainable params
# 11 input features + 1 bias x 6 nodes in first layer
# 6 nodes in first layer + bias x 6 nodes in second layer
# 6 nodes in second layer + bias x 3 nodes in output layer
(15*6) + (7*6) + (7*1)
# Out:
# 139

# %%
model.compile(optimizer='adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
np.random.seed(11)

# %%
model.fit(
    X_train,
    y_train,
    batch_size=3,
    epochs=15,
    verbose=0,
);

# %%
score = model.evaluate(X_test, y_test, verbose=0)

print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.07568380236625671
# Test accuracy: 0.9722222089767456

# %% [markdown]
# How good is actually this test accuracy? Let's have a look at the target variable's class proportions:

# %%
df['label'].value_counts()
# Out:
# 0    130
# 1     48
# Name: label, dtype: int64

# %% [markdown]
# 79.6% of people did not exit. This means that if we would simply predict everyone to not exit, we would be right in 79.6% cases! This is an important benchmark.
#
# Let's also have a look at the confusion matrix:

# %%
y_pred = model.predict(X_test)

y_pred = (y_pred > 0.5) #returns a Boolean for each value!

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm/cm.sum()
# Out:
# array([[0.63888889, 0.        ],
#        [0.        , 0.36111111]])

# %%
ax= plt.subplot()
sns.heatmap(cm, annot=True, fmt='g', ax=ax);  #annot=True to annotate cells, ftm='g' to disable scientific notation
# labels, title and ticks
ax.set_xlabel('Predicted labels'); ax.set_ylabel('True labels') 
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(['continued', 'exited']); ax.yaxis.set_ticklabels(['continued', 'exited']);

# %% [markdown]
# ---
# ## Improving a model
#
# The first model relied on a relatively simple structure and default parameters.
#
#     Which model parameters can we set differently to try improving performance?
#
# Let's consider a number of such parameters, how to change them and what consequences it may have.

# %% [markdown]
# ### Hidden layers and nodes
#
# By increasing the number of hidden layers and nodes in each layer, we can allow our model to capture more complex relationships. At the same time we are risking getting more overfitting and more computational costs, so we should still be cautious with these.
#
# Extra hidden layers can be simply added using `model.add(layers.Dense(...`, and the number of nodes is the correspondent `units=` parameter.

# %% [markdown]
# ### Dropouts
#
# Dropouts have became one of the most popular regularization options. It is usually a good idea to use them for each layer other than the output layer. The dropout percentage may be however hard to choose. Usually values between 0.1 and 0.5 could be used.
#
# We can simply add Dropouts by adding `model.add(layers.Dropout())` after each relevant layer

# %% [markdown]
# ### Different activation functions
#
# `leaky relu` activation function can take care of the lack of learning when the current weights lock us out in relu's flat part. We can simply [change this](https://keras.io/activations/) by tuning relu's `alpha` parameter.
#
# `tanh` activation function can allow us to capture more symmetrical effects and output zero on average, which sometimes helps convergence.
#
# Both of these options are however more computationally expensive than `relu`

# %% [markdown]
# ### Weight initialization
#
# We can change the way the weights are initialized to speed up convergence and avoid local minima. This setting is changed using `kernel_initializer` option for each layer. Note that By default Keras already uses `glorot_uniform` kernel_initializer. We can alternatively use `he_uniform`, which sometimes works better with `relu` activation functions. See the full list of possible [kernel initializers here](https://keras.io/initializers/)

# %% [markdown]
# ### Early Stopping
#
# Stop training when performance on validation data starts increasing. Simple, yet very effective
#
# In Keras this can be achieved by adding `EarlyStopping(monitor='val_loss')` into the `callbacks=[]` option of the `model.fit()` step.

# %% [markdown]
# ### Optimizers
#
# `adam` has shown to be one of the best optimizers in many situations. In some cases however we may want to experiment and use `optimizer='rmsprop'` and `optimizer='nadam'`

# %% [markdown]
# ### Batch size and Epochs
#
# Fitting the model over more epochs can ensure that we do not stop too early (loss still decreasing). Too many epochs however often result in overfitting.
#
# Batch size is usually chosen between 10 and 256 (often as powers of 2), and can be experimented with. The size of the dataset matters for it as well, with smaller datasets usually working better with smaller batch sizes.

# %% [markdown]
# ---
# ## Building a better neural network
#
# Now let's try to combine some of these settings to create a better neural network model:

# %%
np.random.seed(99)
from tensorflow.keras.layers import LeakyReLU

def make_model_2(m_name):
    
    model = Sequential(name=m_name)
    model.add(layers.Dense(name="FullyConnected_1", kernel_initializer='he_uniform', units=24, input_dim=11))
    model.add(layers.LeakyReLU(alpha=0.25))
    model.add(layers.Dropout(0.25))
    model.add(layers.Dense(name="FullyConnected_2", units=12, activation="tanh"))
    model.add(layers.Dropout(0.25))
    model.add(layers.Dense(name="FullyConnected_OutputLayer", units=1, activation="sigmoid"))
    
    return model

model2 = make_model_2("BetterModel")
model2.compile(optimizer='nadam', loss = 'binary_crossentropy', metrics = ['accuracy'])

model2.summary()
# Out:
# Model: "BetterModel"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  FullyConnected_1 (Dense)    (None, 24)                288
#
#  leaky_re_lu (LeakyReLU)     (None, 24)                0
#
#  dropout (Dropout)           (None, 24)                0
#
#  FullyConnected_2 (Dense)    (None, 12)                300
#
#  dropout_1 (Dropout)         (None, 12)                0
#
#  FullyConnected_OutputLayer   (None, 1)                13
#  (Dense)
#
# =================================================================
# Total params: 601
# Trainable params: 601
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import TensorBoard
import time

# %% [markdown]
# To run Tensorboard use `tensorboard --logdir=tb/logs` in the terminal (make sure you are in the right directory, i.e. the one this notebook is located). After running it copy the provided link into your browser

# %%
np.random.seed(999)

es = EarlyStopping(monitor='val_loss', patience=2)

log_dir = os.path.join('tb/logs', f"run_{time.time()}")

model2.fit(
    X_train,
    y_train,
    batch_size=32,
    epochs=100,
    validation_split=0.1,
    verbose=0,
    callbacks=[es, TensorBoard(log_dir, write_graph=True)],
)
score2 = model2.evaluate(X_test, y_test, verbose=0)

print("Test loss:", score2[0])
print("Test accuracy:", score2[1])
# Out:
# Test loss: 0.3638656735420227
# Test accuracy: 0.8535000085830688

# %% [markdown]
# This does not seem to be any better! Seems like making our model more complex has only hurt the test set performance. Perhaps a different / smarter set of parameters would do better?

# %% [markdown]
# ---
# ## Grid search for neural networks
#
# With so many parameters to choose from, how do we know which ones are the best? A good idea could be to try various parameters and select the combination that results in best performance. This can be achieved using Grid search. The number of parameters however should be chosen with caution as each extra parameter dimension may increase the number of models to train exponentially.

# %%
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
#this allows using Keras classifiers inside sklearn!

from sklearn.model_selection import  GridSearchCV

# %%
def make_model_gs(optimizer, units_num, activation_type, third_layer=False):
    
    from tensorflow.keras.layers import Activation, Dense
    
    model = Sequential() 

    model.add(Dense(units=units_num, activation=activation_type, input_dim=11))

    model.add(Dense(units=units_num, activation=activation_type))
    
    if third_layer:
        model.add(Dense(units=units_num, activation=activation_type))
    
    model.add(Dense(units=1, activation='sigmoid'))
    
    model.compile(optimizer = optimizer, loss = 'binary_crossentropy', metrics = ['accuracy'])
    

    return model


#below we define how the classifier is fitted when called
model_gs = KerasClassifier(build_fn = make_model_gs)
# Out:
# C:\Users\651494\AppData\Local\Temp/ipykernel_11800/2763339097.py:23: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead.
#   model_gs = KerasClassifier(build_fn = make_model_gs)

# %%
parameters= {'batch_size':[25,16],
             'epochs':[10, 30],
             'units_num':[6, 12],
             'activation_type':['relu', 'tanh'],
             'optimizer': ['rmsprop', 'adam']}

# %%
grid_search = GridSearchCV(estimator = model_gs,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 3)

# %%
grid_search=grid_search.fit(X_train, y_train)

best_parameters=grid_search.best_params_
best_accuracy=grid_search.best_score_
# Out:
# Epoch 1/10
# 214/214 [==============================] - 1s 1ms/step - loss: 0.5693 - accuracy: 0.7834
# Epoch 2/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4945 - accuracy: 0.7986
# Epoch 3/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4733 - accuracy: 0.7986
# Epoch 4/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4593 - accuracy: 0.7986
# Epoch 5/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4478 - accuracy: 0.7986
# Epoch 6/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4383 - accuracy: 0.7988
# Epoch 7/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4298 - accuracy: 0.8044
# Epoch 8/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4228 - accuracy: 0.8104
# Epoch 9/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4154 - accuracy: 0.8183
# Epoch 10/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4060 - accuracy: 0.8221
# Epoch 1/10
# 214/214 [==============================] - 1s 1ms/step - loss: 0.5753 - accuracy: 0.7643
# Epoch 2/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4983 - accuracy: 0.7902
# Epoch 3/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4762 - accuracy: 0.7902
# Epoch 4/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4612 - accuracy: 0.7902
# Epoch 5/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4490 - accuracy: 0.7904
# Epoch 6/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4391 - accuracy: 0.7907
# Epoch 7/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4308 - accuracy: 0.8001
# Epoch 8/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4241 - accuracy: 0.8097
# Epoch 9/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4183 - accuracy: 0.8183
# Epoch 10/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4135 - accuracy: 0.8213
# Epoch 1/10
# 214/214 [==============================] - 1s 1ms/step - loss: 0.8030 - accuracy: 0.4633
# Epoch 2/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.5627 - accuracy: 0.8013
# Epoch 3/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4847 - accuracy: 0.8060
# Epoch 4/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4428 - accuracy: 0.8153
# Epoch 5/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4223 - accuracy: 0.8183
# Epoch 6/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4103 - accuracy: 0.8234
# Epoch 7/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4027 - accuracy: 0.8271
# Epoch 8/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.3954 - accuracy: 0.8313
# Epoch 9/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.3886 - accuracy: 0.8331
# Epoch 10/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.3822 - accuracy: 0.8375
# Epoch 1/10
# 214/214 [==============================] - 1s 1ms/step - loss: 0.5374 - accuracy: 0.7682
# Epoch 2/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4658 - accuracy: 0.7994
# Epoch 3/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4351 - accuracy: 0.8059
# Epoch 4/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4100 - accuracy: 0.8206
# Epoch 5/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.3915 - accuracy: 0.8299
# Epoch 6/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.3768 - accuracy: 0.8395
# Epoch 7/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.3665 - accuracy: 0.8462
# Epoch 8/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.3594 - accuracy: 0.8517
# Epoch 9/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.3540 - accuracy: 0.8522
# Epoch 10/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.3500 - accuracy: 0.8547
# Epoch 1/10
# 214/214 [==============================] - 1s 1ms/step - loss: 0.5086 - accuracy: 0.7855
# Epoch 2/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4508 - accuracy: 0.7920
# Epoch 3/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4305 - accuracy: 0.8007
# Epoch 4/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4195 - accuracy: 0.8067
# Epoch 5/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4093 - accuracy: 0.8162
# Epoch 6/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.3971 - accuracy: 0.8284
# Epoch 7/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.3849 - accuracy: 0.8397
# Epoch 8/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.3735 - accuracy: 0.8472
# Epoch 9/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.3646 - accuracy: 0.8517
# Epoch 10/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.3574 - accuracy: 0.8547
# Epoch 1/10
# 214/214 [==============================] - 1s 1ms/step - loss: 0.5439 - accuracy: 0.7448
# Epoch 2/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4474 - accuracy: 0.8033
# Epoch 3/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4296 - accuracy: 0.8080
# Epoch 4/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4201 - accuracy: 0.8165
# Epoch 5/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4137 - accuracy: 0.8185
# Epoch 6/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4088 - accuracy: 0.8221
# Epoch 7/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4048 - accuracy: 0.8243
# Epoch 8/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4015 - accuracy: 0.8262
# Epoch 9/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.3982 - accuracy: 0.8277
# Epoch 10/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.3956 - accuracy: 0.8288
# Epoch 1/10
# 214/214 [==============================] - 1s 1ms/step - loss: 0.5104 - accuracy: 0.7859
# Epoch 2/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4528 - accuracy: 0.8016
# Epoch 3/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4352 - accuracy: 0.8063
# Epoch 4/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4244 - accuracy: 0.8087
# Epoch 5/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4166 - accuracy: 0.8108
# Epoch 6/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4090 - accuracy: 0.8172
# Epoch 7/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4016 - accuracy: 0.8200
# Epoch 8/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.3949 - accuracy: 0.8234
# Epoch 9/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.3879 - accuracy: 0.8290
# Epoch 10/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.3812 - accuracy: 0.8329
# Epoch 1/10
# 214/214 [==============================] - 1s 1ms/step - loss: 0.7042 - accuracy: 0.5940
# Epoch 2/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.5332 - accuracy: 0.7810
# Epoch 3/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4847 - accuracy: 0.7905
# Epoch 4/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4598 - accuracy: 0.7937
# Epoch 5/10
# 214/214 [==============================] - 0s 1ms/step - loss: 0.4449 - accuracy: 0.
30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3225 - accuracy: 0.8669
# Epoch 29/30
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3226 - accuracy: 0.8650
# Epoch 30/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3204 - accuracy: 0.8654
# Epoch 1/30
# 334/334 [==============================] - 1s 1ms/step - loss: 0.5356 - accuracy: 0.7407
# Epoch 2/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.4262 - accuracy: 0.8112
# Epoch 3/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.4119 - accuracy: 0.8185
# Epoch 4/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3985 - accuracy: 0.8264
# Epoch 5/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3854 - accuracy: 0.8352
# Epoch 6/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3742 - accuracy: 0.8432
# Epoch 7/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3649 - accuracy: 0.8470
# Epoch 8/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3592 - accuracy: 0.8513
# Epoch 9/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3547 - accuracy: 0.8554
# Epoch 10/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3505 - accuracy: 0.8579
# Epoch 11/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3479 - accuracy: 0.8584
# Epoch 12/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3460 - accuracy: 0.8596
# Epoch 13/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3445 - accuracy: 0.8577
# Epoch 14/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3428 - accuracy: 0.8607
# Epoch 15/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3409 - accuracy: 0.8618
# Epoch 16/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3395 - accuracy: 0.8622
# Epoch 17/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3389 - accuracy: 0.8629
# Epoch 18/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3379 - accuracy: 0.8633
# Epoch 19/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3373 - accuracy: 0.8612
# Epoch 20/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3358 - accuracy: 0.8626
# Epoch 21/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3360 - accuracy: 0.8624
# Epoch 22/30
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3345 - accuracy: 0.8614
# Epoch 23/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3341 - accuracy: 0.8627
# Epoch 24/30
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3338 - accuracy: 0.8611
# Epoch 25/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3336 - accuracy: 0.8614
# Epoch 26/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3333 - accuracy: 0.8609
# Epoch 27/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3326 - accuracy: 0.8624
# Epoch 28/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3317 - accuracy: 0.8609
# Epoch 29/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3314 - accuracy: 0.8642
# Epoch 30/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3317 - accuracy: 0.8627
# Epoch 1/30
# 334/334 [==============================] - 1s 1ms/step - loss: 0.4974 - accuracy: 0.7732
# Epoch 2/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.4052 - accuracy: 0.8219
# Epoch 3/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3902 - accuracy: 0.8275
# Epoch 4/30
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3777 - accuracy: 0.8363
# Epoch 5/30
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3660 - accuracy: 0.8416
# Epoch 6/30
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3586 - accuracy: 0.8472
# Epoch 7/30
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3522 - accuracy: 0.8519
# Epoch 8/30
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3477 - accuracy: 0.8558
# Epoch 9/30
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3447 - accuracy: 0.8577
# Epoch 10/30
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3427 - accuracy: 0.8556
# Epoch 11/30
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3409 - accuracy: 0.8613
# Epoch 12/30
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3387 - accuracy: 0.8624
# Epoch 13/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3365 - accuracy: 0.8665
# Epoch 14/30
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3359 - accuracy: 0.8618
# Epoch 15/30
# 334/334 [==============================] - 1s 1ms/step - loss: 0.3348 - accuracy: 0.8618
# Epoch 16/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3329 - accuracy: 0.8630
# Epoch 17/30
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3323 - accuracy: 0.8643
# Epoch 18/30
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3316 - accuracy: 0.8643
# Epoch 19/30
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3296 - accuracy: 0.8661
# Epoch 20/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3305 - accuracy: 0.8648
# Epoch 21/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3282 - accuracy: 0.8654
# Epoch 22/30
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3280 - accuracy: 0.8631
# Epoch 23/30
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3274 - accuracy: 0.8676
# Epoch 24/30
# 334/334 [==============================] - 1s 3ms/step - loss: 0.3262 - accuracy: 0.8648
# Epoch 25/30
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3263 - accuracy: 0.8661
# Epoch 26/30
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3251 - accuracy: 0.8671
# Epoch 27/30
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3246 - accuracy: 0.8675
# Epoch 28/30
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3240 - accuracy: 0.8660: 0s - loss: 0.3203 - accuracy:
# Epoch 29/30
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3240 - accuracy: 0.8671
# Epoch 30/30
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3231 - accuracy: 0.8650
# Epoch 1/30
# 320/320 [==============================] - 1s 1ms/step - loss: 0.5386 - accuracy: 0.7441
# Epoch 2/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.4145 - accuracy: 0.8181
# Epoch 3/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.4001 - accuracy: 0.8296
# Epoch 4/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.3863 - accuracy: 0.8379
# Epoch 5/30
# 320/320 [==============================] - 0s 2ms/step - loss: 0.3729 - accuracy: 0.8456
# Epoch 6/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.3619 - accuracy: 0.8534
# Epoch 7/30
# 320/320 [==============================] - 0s 2ms/step - loss: 0.3525 - accuracy: 0.8572
# Epoch 8/30
# 320/320 [==============================] - 1s 2ms/step - loss: 0.3468 - accuracy: 0.8585
# Epoch 9/30
# 320/320 [==============================] - 0s 2ms/step - loss: 0.3426 - accuracy: 0.8604
# Epoch 10/30
# 320/320 [==============================] - 0s 2ms/step - loss: 0.3393 - accuracy: 0.8615
# Epoch 11/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.3370 - accuracy: 0.8609
# Epoch 12/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.3362 - accuracy: 0.8612
# Epoch 13/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.3343 - accuracy: 0.8629
# Epoch 14/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.3336 - accuracy: 0.8636
# Epoch 15/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.3328 - accuracy: 0.8633
# Epoch 16/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.3320 - accuracy: 0.8614
# Epoch 17/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.3307 - accuracy: 0.8641
# Epoch 18/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.3308 - accuracy: 0.8630
# Epoch 19/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.3303 - accuracy: 0.8614
# Epoch 20/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.3296 - accuracy: 0.8639
# Epoch 21/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.3292 - accuracy: 0.8615
# Epoch 22/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.3287 - accuracy: 0.8665
# Epoch 23/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.3288 - accuracy: 0.8640
# Epoch 24/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.3279 - accuracy: 0.8641
# Epoch 25/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.3274 - accuracy: 0.8640
# Epoch 26/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.3267 - accuracy: 0.8661
# Epoch 27/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.3267 - accuracy: 0.8660
# Epoch 28/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.3257 - accuracy: 0.8650
# Epoch 29/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.3249 - accuracy: 0.8660
# Epoch 30/30
# 320/320 [==============================] - 0s 1ms/step - loss: 0.3262 - accuracy: 0.8664

# %%
best_parameters

# %%
best_accuracy

# %%
#test accuracy
from sklearn.metrics import accuracy_score

y_pred = grid_search.predict(X_test)
accuracy_score(y_test, y_pred)

# %% [markdown]
# ---
# ## Summary
#
# - Tuning parameters of a deep learning model is really an art
# - Luckily there are multiple heuristics that we can use to try to make our models better (or at least to not make them worse)
# - Searching over a set of parameters to find the best ones is usually a better idea than trying to guess them yourself
# - However, grid searches can be time consuming when working with deep learning models

# %%
# remove tensorboard files
shutil.rmtree('tb')
